# %%
import warnings 
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Data file.csv')
data.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                6                 0.0  29.000000  29.000000      UPW
# 1               12                 0.0   0.000000   0.000000      UPW
# 2                6                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   2.333333   2.333333      UPW
#
#         pdate
# 0  2016-07-20
# 1  2016-08-10
# 2  2016-08-19
# 3  2016-06-06
# 4  2016-06-22
#
# [5 rows x 37 columns]

# %%
data.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data.shape
# Out:
# (209593, 36)

# %%
data.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                6                 0.0  29.000000  29.000000      UPW
# 1               12                 0.0   0.000000   0.000000      UPW
# 2                6                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   2.333333   2.333333      UPW
#
#         pdate
# 0  2016-07-20
# 1  2016-08-10
# 2  2016-08-19
# 3  2016-06-06
# 4  2016-06-22
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Checking data types of each column

# %%
data.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# dtype: object

# %%
data.label.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.msisdn
# Out:
# 0         21408I70789
# 1         76462I70374
# 2         17943I70372
# 3         55773I70781
# 4         03813I82730
#              ...
# 209588    22758I85348
# 209589    95583I84455
# 209590    28556I85350
# 209591    59712I82733
# 209592    65061I85339
# Name: msisdn, Length: 209593, dtype: object

# %% [markdown]
# - Removing mobile number of user column(msisdn) as it's not relevent input feature

# %%
data.drop(columns=['msisdn'],inplace=True)

# %% [markdown]
# #### Data Set Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
# label                   209593 non-null int64
# aon                     209593 non-null float64
# daily_decr30            209593 non-null float64
# daily_decr90            209593 non-null float64
# rental30                209593 non-null float64
# rental90                209593 non-null float64
# last_rech_date_ma       209593 non-null float64
# last_rech_date_da       209593 non-null float64
# last_rech_amt_ma        209593 non-null int64
# cnt_ma_rech30           209593 non-null int64
# fr_ma_rech30            209593 non-null float64
# sumamnt_ma_rech30       209593 non-null float64
# medianamnt_ma_rech30    209593 non-null float64
# medianmarechprebal30    209593 non-null float64
# cnt_ma_rech90           209593 non-null int64
# fr_ma_rech90            209593 non-null int64
# sumamnt_ma_rech90       209593 non-null int64
# medianamnt_ma_rech90    209593 non-null float64
# medianmarechprebal90    209593 non-null float64
# cnt_da_rech30           209593 non-null float64
# fr_da_rech30            209593 non-null float64
# cnt_da_rech90           209593 non-null int64
# fr_da_rech90            209593 non-null int64
# cnt_loans30             209593 non-null int64
# amnt_loans30            209593 non-null int64
# maxamnt_loans30         209593 non-null float64
# medianamnt_loans30      209593 non-null float64
# cnt_loans90             209593 non-null float64
# amnt_loans90            209593 non-null int64
# maxamnt_loans90         209593 non-null int64
# medianamnt_loans90      209593 non-null float64
# payback30               209593 non-null float64
# payback90               209593 non-null float64
# pcircle                 209593 non-null object
# pdate                   209593 non-null object
# dtypes: float64(21), int64(12), object(2)
# memory usage: 56.0+ MB

# %% [markdown]
# - There are object data types in two columns pcircle and pdate

# %%
data.pcircle.unique()
# Out:
# array(['UPW'], dtype=object)

# %%
data.pdate.head()
# Out:
# 0    2016-07-20
# 1    2016-08-10
# 2    2016-08-19
# 3    2016-06-06
# 4    2016-06-22
# Name: pdate, dtype: object

# %%
data.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %% [markdown]
# - There is no null value present in any column

# %% [markdown]
# #### Checking duplicated values

# %%
data.duplicated().sum()
# Out:
# 31

# %% [markdown]
# - Found there are 31 duplicated rows in this data set

# %% [markdown]
# Checking the duplicated values

# %%
duplicate_index=data[data.duplicated()==True].index
duplicate_index
# Out:
# Int64Index([ 35769,  49751,  51852,  57581,  68296,  90887,  94430,  98092,
#             111140, 124619, 135203, 137416, 138582, 151181, 151753, 159521,
#             160902, 162585, 163854, 174785, 183632, 188369, 192053, 193897,
#             195633, 196936, 197408, 198194, 198511, 199729, 203773],
#            dtype='int64')

# %%
for x in data.index:
    if x==35759:
        continue
        
    elif np.array_equal(data.iloc[x],data.iloc[35769]):
        print(x)
# Out:
# 9306
# 35769

# %%
data.iloc[[9306]]
# Out:
#       label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 9306      0  118.0           0.0           0.0       0.0       0.0
#
#       last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 9306                0.0                0.0                 0              0
#
#       ...  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 9306  ...              6.0                 0.0          1.0             6
#
#       maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 9306                6                 0.0        0.0        0.0      UPW
#
#            pdate
# 9306  2016-06-12
#
# [1 rows x 35 columns]

# %%
data.iloc[[35769]]
# Out:
#        label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 35769      0  118.0           0.0           0.0       0.0       0.0
#
#        last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 35769                0.0                0.0                 0              0
#
#        ...  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 35769  ...              6.0                 0.0          1.0             6
#
#        maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 35769                6                 0.0        0.0        0.0      UPW
#
#             pdate
# 35769  2016-06-12
#
# [1 rows x 35 columns]

# %% [markdown]
# - Hence data set contains 31 duplicated rows we have to remove these duplicated row

# %% [markdown]
# #### Removing duplicated rows from dataset

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Statistical Describtion data

# %%
data.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209562.000000  209562.000000  209562.000000  209562.000000
# mean        0.875297    8113.512796    5382.170031    6083.386523
# std         0.330383   75701.620014    9221.086606   10919.382966
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.480000      42.713250
# 50%         1.000000     527.000000    1470.465667    1500.000000
# 75%         1.000000     982.000000    7246.000000    7804.000000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209562.000000  209562.000000      209562.000000      209562.000000
# mean     2692.964058    3483.905668        3756.403389        3712.752058
# std      4308.784971    5770.737718       53909.859829       53378.762010
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# 25%       280.800000     300.370000           1.000000           0.000000
# 50%      1083.940000    1334.400000           3.000000           0.000000
# 75%      3357.452500    4202.537500           7.000000           0.000000
# max    198926.110000  200148.110000      998650.377733      999171.809410
#
#        last_rech_amt_ma  cnt_ma_rech30  ...    cnt_loans30   amnt_loans30  \
# count     209562.000000  209562.000000  ...  209562.000000  209562.000000
# mean        2064.754512       3.978622  ...       2.759226      17.953703
# std         2370.831005       4.256138  ...       2.554603      17.380433
# min            0.000000       0.000000  ...       0.000000       0.000000
# 25%          770.000000       1.000000  ...       1.000000       6.000000
# 50%         1539.000000       3.000000  ...       2.000000      12.000000
# 75%         2309.000000       5.000000  ...       4.000000      24.000000
# max        55000.000000     203.000000  ...      50.000000     306.000000
#
#        maxamnt_loans30  medianamnt_loans30    cnt_loans90   amnt_loans90  \
# count    209562.000000       209562.000000  209562.000000  209562.000000
# mean        274.698489            0.054037      18.523497      23.647923
# std        4245.577376            0.218054     224.813949      26.470977
# min           0.000000            0.000000       0.000000       0.000000
# 25%           6.000000            0.000000       1.000000       6.000000
# 50%           6.000000            0.000000       2.000000      12.000000
# 75%           6.000000            0.000000       5.000000      30.000000
# max       99864.560864            3.000000    4997.517944     438.000000
#
#        maxamnt_loans90  medianamnt_loans90      payback30      payback90
# count    209562.000000       209562.000000  209562.000000  209562.000000
# mean          6.703238            0.046084       3.399125       4.321920
# std           2.104003            0.200706       8.813867      10.308399
# min           0.000000            0.000000       0.000000       0.000000
# 25%           6.000000            0.000000       0.000000       0.000000
# 50%           6.000000            0.000000       0.000000       1.666667
# 75%           6.000000            0.000000       3.750000       4.500000
# max          12.000000            3.000000     171.500000     171.500000
#
# [8 rows x 33 columns]

# %% [markdown]
# #### Splitting Data to input and output features

# %%
X=data.drop(columns=['label','pcircle','pdate'])
X.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0  272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 1  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 2  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 3  241.0     21.228000     21.228000    159.42    159.42               41.0
# 4  947.0    150.619333    150.619333   1098.90   1098.90                4.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                0.0              1539              2          21.0  ...
# 1                0.0              5787              1           0.0  ...
# 2                0.0              1539              1           0.0  ...
# 3                0.0               947              0           0.0  ...
# 4                0.0              2309              7           2.0  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 0            2            12              6.0                 0.0
# 1            1            12             12.0                 0.0
# 2            1             6              6.0                 0.0
# 3            2            12              6.0                 0.0
# 4            7            42              6.0                 0.0
#
#    cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0          2.0            12                6                 0.0  29.000000
# 1          1.0            12               12                 0.0   0.000000
# 2          1.0             6                6                 0.0   0.000000
# 3          2.0            12                6                 0.0   0.000000
# 4          7.0            42                6                 0.0   2.333333
#
#    payback90
# 0  29.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   2.333333
#
# [5 rows x 32 columns]

# %%
Y=data.label
Y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=.30)

# %% [markdown]
# #### Checking unique values in each feaeture columns

# %%
for col in X.columns:
    print(f'Unique values in column {col} = {len(data[col].unique())}')
# Out:
# Unique values in column aon = 4507
# Unique values in column daily_decr30 = 147026
# Unique values in column daily_decr90 = 158670
# Unique values in column rental30 = 132148
# Unique values in column rental90 = 141033
# Unique values in column last_rech_date_ma = 1186
# Unique values in column last_rech_date_da = 1174
# Unique values in column last_rech_amt_ma = 70
# Unique values in column cnt_ma_rech30 = 71
# Unique values in column fr_ma_rech30 = 1083
# Unique values in column sumamnt_ma_rech30 = 15141
# Unique values in column medianamnt_ma_rech30 = 510
# Unique values in column medianmarechprebal30 = 30428
# Unique values in column cnt_ma_rech90 = 110
# Unique values in column fr_ma_rech90 = 89
# Unique values in column sumamnt_ma_rech90 = 31771
# Unique values in column medianamnt_ma_rech90 = 608
# Unique values in column medianmarechprebal90 = 29785
# Unique values in column cnt_da_rech30 = 1066
# Unique values in column fr_da_rech30 = 1072
# Unique values in column cnt_da_rech90 = 27
# Unique values in column fr_da_rech90 = 46
# Unique values in column cnt_loans30 = 40
# Unique values in column amnt_loans30 = 48
# Unique values in column maxamnt_loans30 = 1050
# Unique values in column medianamnt_loans30 = 6
# Unique values in column cnt_loans90 = 1110
# Unique values in column amnt_loans90 = 69
# Unique values in column maxamnt_loans90 = 3
# Unique values in column medianamnt_loans90 = 6
# Unique values in column payback30 = 1363
# Unique values in column payback90 = 2381

# %%
from sklearn.ensemble import RandomForestClassifier
rmodel=RandomForestClassifier()

# %%
rmodel.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
ypred=rmodel.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(ytest,ypred)*100
# Out:
# 91.28982487394424

# %%
confusion_matrix(ytest,ypred)
# Out:
# array([[ 3434,  4388],
#        [ 1088, 53959]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
plt.xlabel('Actual')
plt.ylabel('Predict')
plt.show()

# %%
data.label.value_counts()
# Out:
# 1    183429
# 0     26133
# Name: label, dtype: int64

# %% [markdown]
# Hence the dataset is Unbalance we need to it as balanced dataset

# %%
nondefaulter=data[data.label==1]
defaulter=data[data.label==0]

# %%
from sklearn.utils import resample

# %%
default_sampled=resample(defaulter,n_samples=len(nondefaulter))

# %%
default_sampled
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 70907       0  1383.0   2805.000000   2805.000000  11567.62  12412.90
# 171858      0  1296.0     19.933333     19.933333   1061.58   1061.58
# 11196       0  1593.0      0.000000      0.000000    333.92    333.92
# 189225      0   334.0      0.000000      0.000000      0.00      0.00
# 126070      0   150.0   3456.200000   3456.500000  10215.15  10293.45
# ...       ...     ...           ...           ...       ...       ...
# 63037       0  1757.0      5.516000      5.516000     20.37     20.37
# 176882      0   918.0   3560.508000   3576.830000   3806.88   3978.12
# 99800       0   160.0     34.650000     34.650000   4004.64   4004.64
# 35018       0   822.0   3051.820000   3077.730000   2347.80   3521.70
# 75039       0    57.0      5.166667      5.166667    585.50    585.50
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 70907                 2.0                0.0              2309              1
# 171858                3.0                0.0              1539              3
# 11196                 0.0                0.0                 0              0
# 189225                0.0                0.0                 0              0
# 126070               10.0                0.0              1924              1
# ...                   ...                ...               ...            ...
# 63037                 0.0                0.0                 0              0
# 176882                2.0                0.0              1547             12
# 99800                 2.0                0.0               773              5
# 35018                22.0                0.0             10000              1
# 75039                 4.0                0.0              1539              1
#
#         ...  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 70907   ...              6.0                 0.0          1.0             6
# 171858  ...              6.0                 0.0          4.0            24
# 11196   ...              6.0                 0.0          1.0             6
# 189225  ...              6.0                 0.0          1.0             6
# 126070  ...              6.0                 0.0          2.0            12
# ...     ...              ...                 ...          ...           ...
# 63037   ...              6.0                 0.0          1.0             6
# 176882  ...             12.0                 0.0         10.0            72
# 99800   ...              6.0                 0.0          2.0            12
# 35018   ...              6.0                 0.0          1.0             6
# 75039   ...              6.0                 0.0          2.0            12
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 70907                 6                 0.0   0.000000   0.000000      UPW
# 171858                6                 0.0   4.333333   4.333333      UPW
# 11196                 6                 0.0   0.000000   0.000000      UPW
# 189225                6                 0.0   0.000000   0.000000      UPW
# 126070                6                 0.0   0.000000   0.000000      UPW
# ...                 ...                 ...        ...        ...      ...
# 63037                 6                 0.0   0.000000   0.000000      UPW
# 176882               12                 0.0   6.500000   6.500000      UPW
# 99800                 6                 0.0  21.000000  21.000000      UPW
# 35018                 6                 0.0   0.000000   0.000000      UPW
# 75039                 6                 0.0   0.000000   0.000000      UPW
#
#              pdate
# 70907   2016-07-12
# 171858  2016-06-13
# 11196   2016-06-08
# 189225  2016-07-03
# 126070  2016-07-18
# ...            ...
# 63037   2016-06-21
# 176882  2016-07-02
# 99800   2016-06-27
# 35018   2016-07-10
# 75039   2016-06-10
#
# [183429 rows x 35 columns]

# %%
upsampled=pd.concat([nondefaulter,default_sampled])

# %%
upsampled.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
# 5      1  568.0   2257.362667   2261.460000    368.13    380.13
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 1               20.0                0.0              5787              1  ...
# 2                3.0                0.0              1539              1  ...
# 3               41.0                0.0               947              0  ...
# 4                4.0                0.0              2309              7  ...
# 5                2.0                0.0              1539              4  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# 3              6.0                 0.0          2.0            12
# 4              6.0                 0.0          7.0            42
# 5              6.0                 0.0          3.0            18
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 1               12                 0.0   0.000000   0.000000      UPW
# 2                6                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   2.333333   2.333333      UPW
# 5                6                 0.0  11.000000   8.333333      UPW
#
#         pdate
# 1  2016-08-10
# 2  2016-08-19
# 3  2016-06-06
# 4  2016-06-22
# 5  2016-07-02
#
# [5 rows x 35 columns]

# %%
upsampled.label.value_counts()
# Out:
# 1    183429
# 0    183429
# Name: label, dtype: int64

# %%
xdata=upsampled.drop(columns=['label','pcircle','pdate'])
xdata.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 1  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 2  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 3  241.0     21.228000     21.228000    159.42    159.42               41.0
# 4  947.0    150.619333    150.619333   1098.90   1098.90                4.0
# 5  568.0   2257.362667   2261.460000    368.13    380.13                2.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 1                0.0              5787              1           0.0  ...
# 2                0.0              1539              1           0.0  ...
# 3                0.0               947              0           0.0  ...
# 4                0.0              2309              7           2.0  ...
# 5                0.0              1539              4          10.0  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 1            1            12             12.0                 0.0
# 2            1             6              6.0                 0.0
# 3            2            12              6.0                 0.0
# 4            7            42              6.0                 0.0
# 5            3            18              6.0                 0.0
#
#    cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 1          1.0            12               12                 0.0   0.000000
# 2          1.0             6                6                 0.0   0.000000
# 3          2.0            12                6                 0.0   0.000000
# 4          7.0            42                6                 0.0   2.333333
# 5          3.0            18                6                 0.0  11.000000
#
#    payback90
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   2.333333
# 5   8.333333
#
# [5 rows x 32 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mnx=MinMaxScaler()

# %%
xdata=pd.DataFrame(columns=xdata.columns,
                   data=mnx.fit_transform(xdata))

# %%
xdata.head()
# Out:
#         aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0  0.000760      0.045918      0.038094  0.123183  0.126349
# 1  0.000583      0.005605      0.004649  0.110648  0.113936
# 2  0.000289      0.000429      0.000356  0.107322  0.110642
# 3  0.000995      0.000916      0.000760  0.111541  0.114820
# 4  0.000616      0.008835      0.007341  0.108259  0.111624
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0           0.000049           0.000029          0.105218       0.004926
# 1           0.000032           0.000029          0.027982       0.004926
# 2           0.000070           0.000029          0.017218       0.000000
# 3           0.000033           0.000029          0.041982       0.034483
# 4           0.000031           0.000029          0.027982       0.019704
#
#    fr_ma_rech30  ...  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0      0.000000  ...         0.02      0.039216          0.00012
# 1      0.000000  ...         0.02      0.019608          0.00006
# 2      0.000000  ...         0.04      0.039216          0.00006
# 3      0.000002  ...         0.14      0.137255          0.00006
# 4      0.000010  ...         0.06      0.058824          0.00006
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0     0.000200      0.027397              1.0
# 1                 0.0     0.000200      0.013699              0.5
# 2                 0.0     0.000400      0.027397              0.5
# 3                 0.0     0.001401      0.095890              0.5
# 4                 0.0     0.000600      0.041096              0.5
#
#    medianamnt_loans90  payback30  payback90
# 0                 0.0   0.000000   0.000000
# 1                 0.0   0.000000   0.000000
# 2                 0.0   0.000000   0.000000
# 3                 0.0   0.013605   0.013605
# 4                 0.0   0.064140   0.048591
#
# [5 rows x 32 columns]

# %%
ydata=upsampled.label
ydata.head()
# Out:
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# Name: label, dtype: int64

# %% [markdown]
# #### Finding best random_state value for train_test_split

# %%
maxacc=0
maxrs=0
for rs in range(1,50):
    xtrain,xtest,ytrain,ytest=train_test_split(xdata,ydata,test_size=.3,random_state=rs)
    rmodel=RandomForestClassifier()
    rmodel.fit(xtrain,ytrain)
    ypred=rmodel.predict(xtest)
    acc=accuracy_score(ytest,ypred)
    
    if acc>maxacc:
        maxacc=acc
        maxrs=rs
        
print(f'Maximum accuracy= {maxacc} at random_state= {maxrs}')
# Out:
# Maximum accuracy= 0.9759763034036599 at random_state= 4

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xdata,ydata,test_size=.3,random_state=maxrs)

# %%
rmodel=RandomForestClassifier()
rmodel.fit(xtrain,ytrain)
ypred=rmodel.predict(xtest)
accuracy_score(ytest,ypred)
# Out:
# 0.9762307147140599

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# #### Checking accuracy using different models

# %%
tmodel=DecisionTreeClassifier()
tmodel.fit(xtrain,ytrain)
tpred=tmodel.predict(xtest)
accuracy_score(ytest,tpred)
# Out:
# 0.9514437841865199

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
svc=SVC()
svc.fit(xtrain,ytrain)
ypred=svc.predict(xtest)
accuracy_score(ytest,ypred)
# Out:
# 0.7666412255356266

# %%
knn=KNeighborsClassifier()
knn.fit(xtrain,ytrain)
ypred=knn.predict(xtest)
accuracy_score(ytest,ypred)
# Out:
# 0.864262479783387

# %% [markdown]
# #### Cross_validation score of different models

# %%
from sklearn.model_selection import cross_val_score

# %%
s_rmodel=cross_val_score(rmodel,xdata,ydata,cv=5).mean()
s_rmodel
# Out:
# 0.9784412512180932

# %%
s_knn=cross_val_score(knn,xdata,ydata,cv=5).mean()
s_knn
# Out:
# 0.8759547278759305

# %%
t_tmodel=cross_val_score(tmodel,xdata,ydata,cv=5).mean()
t_tmodel
# Out:
# 0.9553396667808931

# %%
from sklearn.metrics import classification_report,f1_score

# %%
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     55135
#            1       1.00      0.95      0.98     54923
#
#     accuracy                           0.98    110058
#    macro avg       0.98      0.98      0.98    110058
# weighted avg       0.98      0.98      0.98    110058

# %%
f1_score(ytest,ypred)
# Out:
# 0.9756673797786253
